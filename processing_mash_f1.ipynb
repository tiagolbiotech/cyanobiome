# %% [markdown]
# `2019-09-07` `Tiago Ferreira Leao` **v1.0**

# %% [markdown]
# # Cyanobiome MASH

# %% [markdown]
# ```
# Requirements: packages below
#               'master_df-TFL190425.txt' (run processing_master_df_datasetS1.ipynb)
# ```

# %% [markdown]
# **Importing General Dependencies**

# %%
import numpy as np
import pandas as pd
import glob
import subprocess
import os
import time
import re
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import islice
from sys import argv
from Bio import SeqIO
# %matplotlib inline
sns.set()

# %% [markdown]
# **Installing MASH**

# %%
if os.path.exists("/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash"):
    print("MASH already downloaded")
else:
    # !wget https://github.com/marbl/Mash/releases/download/v2.0/mash-Linux64-v2.0.tar
    # !tar xopf mash-Linux64-v2.0.tar; rm mash-Linux64-v2.0.tar
# Out:
# MASH already downloaded

# %% [markdown]
# **Download NCBI genomes**

# %% [markdown]
# Search for cyanobacteria at [this link here](https://www.ncbi.nlm.nih.gov/Traces/wgs/?page=1&view=all&search=cyanobacteria)
#
# Download file using the download button
#
# Upload the file into your server and Jupyter interface and then run the cell below

# %%
start_time = time.time()

if os.path.exists("./inputs/wgs_selector.csv"):
    commands = []
    count = 0
    # !cat ./ods/wgs_selector.csv | tr "\t" "~" | cut -d"~" -f1 | sed 1d > ./ids.txt
    with open("./ids.txt") as ids:
        for code in ids:
            prefix = code.strip("\n")[:6]
            line = "wget 'ftp://ftp.ncbi.nlm.nih.gov/sra/wgs_aux/%s/%s/%s/%s.1.fsa_nt.gz' -O - | gunzip > ./ods/%s.fasta"%(prefix[0:2],prefix[2:4],prefix,prefix,prefix)
            commands.append(line)
    table1_handle = open('./download_cyanobacteria.sh', "w")
    cmd_df = pd.DataFrame(commands)
    cmd_df.to_csv(table1_handle, sep='\t', index=False, header=False)
    table1_handle.close()
    # !rm ./ods/ids.txt
else:
    # !mkdir ./ods
    raise ValueError("File ./ods/wgs_selector.txt not found, please upload the file inside the folder ./ods")

# !sh ./ods/download_cyanobacteria.sh
    
print('\n' + "--- %s seconds ---" %(time.time()-start_time))

# %% [markdown]
# **Renaming NCBI**

# %%
def split_at(s, c, n):
    words = s.split(c)
    return c.join(words[:n]), c.join(words[n:])

def rename(filename, outpath):
    strain = split_at(os.path.basename(filename), '_', 1)[0]
    new_file = []
    input_handle = open("%s"%filename, "rU")
    for record in SeqIO.parse(input_handle, "fasta"):
        substring = split_at(record.id, '_', 2)[0]
        new_id = "%s_%s"%(strain,substring)
        record.id = "%s"%new_id
        record.description = "%s"%new_id
        new_file.append(record)
    output_handle = open("%s/%s.ren.fasta"%(outpath,strain), "w")
    SeqIO.write(new_file, output_handle, "fasta")
    output_handle.close()
    input_handle.close()

count = 0

for file in os.listdir("/home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/"):
    if file.endswith(".fasta"):
        rename(os.path.join("/home/gerwick-lab/Desktop/data/genomes/refseq_cyano/",
                            file),
                            '/home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/')
        count += 1

print("%s fasta files were renamed"%count)

# %% [markdown]
# **Sketching NCBI dataset**

# %% [markdown]
# This step is going to create the minhashes from the references to be probed in the soon to be queried genomes

# %%
start_time = time.time()

if os.path.exists("/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/ncbi_genomes.msh"):
    print("Sketch already exists")
else:
    # !./mash-Linux64-v2.0/mash sketch -o /home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/ncbi_genomes /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/*.fasta
    
print('\n' + "--- %s seconds ---" %(time.time()-start_time))
# Out:
# Sketch already exists
#
# --- 0.00106596946716 seconds ---

# %% [markdown]
# **Cateloging NCBI genomes into their respective genera**

# %%
from Bio import SeqIO

def split_string_at(s, c, n):
    words = s.split(c)
    return c.join(words[:n]), c.join(words[n:])

def extract_ncbi_taxa(inputs_folder):
    input_list = glob.glob("%s*.fasta"%inputs_folder)
    taxa = {}
    for item in input_list:
        records = list(SeqIO.parse(item, "fasta"))
        strain = os.path.splitext(os.path.basename(item))[0]
        if records:
            if "TPA_asm" in str(records[0]):
                genera = split_string_at(genera,":",1)[0]
            else:
                genera = split_string_at(records[0].description," ",1)[1]
            if "Candidatus" in str(genera):
                taxa[strain] = str(genera).partition(' ')[2].partition(' ')[0]
            else:
                taxa[strain] = str(genera).partition(' ')[0].lstrip("[").rstrip("]")
    return taxa
            
taxa_dict = extract_ncbi_taxa("/home/gerwick-lab/Desktop/data/genomes/refseq_cyano/")

# %%
taxa_dict
# Out:
# {'AADV02': 'Crocosphaera',
#  'AANO01': 'Synechococcus',
#  'AANP01': 'Synechococcus',
#  'AAOK01': 'Synechococcus',
#  'AATZ01': 'Synechococcus',
#  'AAUA01': 'Synechococcus',
#  'AAVU01': 'Lyngbya',
#  'AAVW01': 'Nodularia',
#  'AAXW01': 'Cyanothece',
#  'AAZV01': 'Leptolyngbya',
#  'ABRS01': 'Coleofasciculus',
#  'ABRV01': 'Synechococcus',
#  'ABSE01': 'Cyanobium',
#  'ABYK01': 'Arthrospira',
#  'ACDW01': 'Prochlorococcus',
#  'ACSK03': 'Arthrospira',
#  'ACYA01': 'Cylindrospermopsis',
#  'ACYB01': 'Raphidiopsis',
#  'ADXL01': 'Synechococcus',
#  'ADXM01': 'Synechococcus',
#  'AEPQ01': 'Moorea',
#  'AESD01': 'Crocosphaera',
#  'AFEJ01': 'Acaryochloris',
#  'AFJC01': 'Microcoleus',
#  'AFXD01': 'Arthrospira',
#  'AGCR01': 'Tolypothrix',
#  'AGIK01': 'Synechococcus',
#  'AGIZ01': 'Fischerella',
#  'AGJC02': 'Cyanothece',
#  'AHGV01': 'Thermanaerovibrio',
#  'AJHB01': 'Microcystis',
#  'AJLJ01': 'Fischerella',
#  'AJLK01': 'Fischerella',
#  'AJLL01': 'Fischerella',
#  'AJLM01': 'Chlorogloeopsis',
#  'AJLN01': 'Chlorogloeopsis',
#  'AJTX02': 'Prochlorothrix',
#  'AJUB01': 'Oscillatoriales',
#  'AJUS01': 'Microcystis',
#  'AJUT01': 'Microcystis',
#  'AJUU01': 'Microcystis',
#  'AJWF01': 'Anabaena',
#  'AJYB01': 'Planococcus',
#  'ALPB01': 'Prochlorococcus',
#  'ALPC01': 'Prochlorococcus',
#  'ALPD01': 'Prochlorococcus',
#  'ALPE01': 'Prochlorococcus',
#  'ALPF01': 'Prochlorococcus',
#  'ALPG01': 'Prochlorococcus',
#  'ALPH01': 'Prochlorococcus',
#  'ALPI01': 'Prochlorococcus',
#  'ALPJ01': 'Prochlorococcus',
#  'ALPK01': 'Prochlorococcus',
#  'ALPL01': 'Prochlorococcus',
#  'ALVI01': 'Kamptonema',
#  'ALVJ01': 'Calothrix',
#  'ALVK01': 'Pseudanabaena',
#  'ALVL01': 'Pleurocapsa',
#  'ALVM01': 'Leptolyngbya',
#  'ALVN01': 'Leptolyngbya',
#  'ALVO01': 'Geminocystis',
#  'ALVP01': 'Nodosilinea',
#  'ALVQ01': 'Spirulina',
#  'ALVR01': 'Spirulina',
#  'ALVS01': 'Fischerella',
#  'ALVT01': 'Fischerella',
#  'ALVU02': 'Synechocystis',
#  'ALVV02': 'Leptolyngbya',
#  'ALVW01': 'Mastigocladopsis',
#  'ALVX01': 'Fischerella',
#  'ALVY01': 'Gloeocapsa',
#  'ALVZ01': 'Xenococcus',
#  'ALWA01': 'Cyanobacterium',
#  'ALWB01': 'Pseudanabaena',
#  'ALWC01': 'Synechococcus',
#  'ALWD01': 'Scytonema',
#  'ANFJ01': 'Fortiea',
#  'ANFQ01': 'Geitlerinema',
#  'ANKN01': 'Prochlorothrix',
#  'ANKO01': 'Oscillatoria',
#  'ANKQ01': 'Microcystis',
#  'ANNX02': 'Scytonema',
#  'AOCI01': 'Microcystis',
#  'APIY01': 'Dolichospermum',
#  'APIZ01': 'Dolichospermum',
#  'AQPY01': 'Microcystis',
#  'ARCP01': 'Filamentous',
#  'ASAK01': 'Planktothrix',
#  'ASSJ01': 'Rubidibacter',
#  'ASZQ01': 'Microcystis',
#  'AUMZ01': 'Synechococcus',
#  'AUNA01': 'Synechococcus',
#  'AUSW01': 'Psychrobacter',
#  'AUZM01': 'Lyngbya',
#  'AVFS01': 'Planktothrix',
#  'AVFT01': 'Planktothrix',
#  'AVFU01': 'Planktothrix',
#  'AVFV01': 'Planktothrix',
#  'AVFW01': 'Planktothrix',
#  'AVFX01': 'Planktothrix',
#  'AVFY01': 'Planktothrix',
#  'AVFZ01': 'Planktothrix',
#  'AWNH01': 'Leptolyngbya',
#  'AXAQ01': 'Mastigocoleus',
#  'AXUV01': 'Synechococcus',
#  'AXUW01': 'Synechococcus',
#  'AXUX01': 'Synechococcus',
#  'AXZO01': 'Synechococcus',
#  'AZXL01': 'Synechococcus',
#  'AZYY01': 'Aphanizomenon',
#  'BAUB01': 'Synechococcus',
#  'BAWS01': 'Synechococcus',
#  'BBPA01': 'Microcystis',
#  'BBWW01': 'Leptolyngbya',
#  'BDGE01': 'Nostoc',
#  'BDSM01': 'Microcystis',
#  'BDUB01': 'Nodularia',
#  'BDUC01': 'Tolypothrix',
#  'BEIU01': 'Microcystis',
#  'BEYQ01': 'Microcystis',
#  'BFAC01': 'Microcystis',
#  'CACA01': 'Oscillatoria',
#  'CAFN01': 'Arthrospira',
#  'CAIH01': 'Microcystis',
#  'CAII01': 'Microcystis',
#  'CAIJ01': 'Microcystis',
#  'CAIK01': 'Microcystis',
#  'CAIL01': 'Microcystis',
#  'CAIM01': 'Microcystis',
#  'CAIN01': 'Microcystis',
#  'CAIO01': 'Microcystis',
#  'CAIP01': 'Microcystis',
#  'CAIQ01': 'Microcystis',
#  'CAIS01': 'Richelia',
#  'CAIY01': 'Richelia',
#  'CAQK01': 'Crocosphaera',
#  'CAQL01': 'Crocosphaera',
#  'CAQM01': 'Crocosphaera',
#  'CAQN01': 'Crocosphaera',
#  'CBZS01': 'Richelia',
#  'CDHJ01': 'Aphanizomenon',
#  'CVSV01': 'Prochlorococcus',
#  'CVSW01': 'Prochlorococcus',
#  'CVSX01': 'Prochlorococcus',
#  'CVSY01': 'Prochlorococcus',
#  'CVSZ01': 'Prochlorococcus',
#  'CZCS01': 'Planktothrix',
#  'CZCT02': 'Planktothrix',
#  'CZCU01': 'Planktothrix',
#  'CZCZ01': 'Planktothrix',
#  'CZDF01': 'Planktothrix',
#  'DAZV01': 'Prochlorococcus',
#  'DAZW01': 'Anabaena',
#  'DAZX01': 'Planktothrix',
#  'DBAX01': 'Prochlorococcus',
#  'DBCX01': 'Rhodoferax',
#  'DBIX01': 'Leptolyngbya',
#  'DBVD01': 'Cyanobium',
#  'DBVH01': 'Prochlorococcus',
#  'DBXD01': 'Microcystis',
#  'DBYM01': 'Prochlorococcus',
#  'DCNZ01': 'Anabaena',
#  'DCQC01': 'Aphanizomenon',
#  'DCSN01': 'Cyanobacteria',
#  'DDLS01': 'Anabaena',
#  'DDVE01': 'Cyanothece',
#  'DEDY01': 'Nostoc',
#  'DEEH01': 'Prochlorococcus',
#  'DEEN01': 'Phormidium',
#  'DEFJ01': 'Cyanobacteria',
#  'DEGT01': 'Microcystis',
#  'DEGZ01': 'Aphanizomenon',
#  'DESS01': 'Chroococcidiopsis',
#  'DESZ01': 'Nostoc',
#  'DFEL01': 'Prochlorococcus',
#  'DFQU01': 'Tolypothrix',
#  'DFRI01': 'Cyanobium',
#  'DFVO01': 'Richelia',
#  'DFYB01': 'Synechococcus',
#  'DGBR01': 'Aphanizomenon',
#  'DGDG01': 'Prochlorococcus',
#  'DGDH01': 'Prochlorococcus',
#  'DGYA01': 'Fischerella',
#  'DHMN01': 'Fischerella',
#  'DIYQ01': 'Mastigocoleus',
#  'DIYT01': 'Prochlorococcus',
#  'DJOE01': 'Crocosphaera',
#  'DJQF01': 'Prochlorococcus',
#  'DJYG01': 'Fischerella',
#  'DJYZ01': 'Cylindrospermopsis',
#  'DKMR01': 'Cyanobacteria',
#  'DKOB01': 'Cyanobium',
#  'DKOE01': 'Synechococcus',
#  'DKRT01': 'Prochlorococcus',
#  'DLDG01': 'Thermanaerovibrio',
#  'DLDQ01': 'Trichormus',
#  'DLEF01': 'Phormidium',
#  'DLEZ01': 'Synechocystis',
#  'DLGM01': 'Planktothrix',
#  'DLLM01': 'Prochlorococcus',
#  'DLPW01': 'Prochlorococcus',
#  'DLSU01': 'Filamentous',
#  'FITM01': 'Synechococcus',
#  'FSSI02': 'Oscillatoria',
#  'FXBO01': 'Synechococcus',
#  'FXWN01': 'Synechococcus',
#  'FYBH01': 'Calothrix',
#  'JENA01': 'Synechococcus',
#  'JFKN01': 'Prochlorococcus',
#  'JFKO01': 'Prochlorococcus',
#  'JFKP01': 'Prochlorococcus',
#  'JFKQ01': 'Prochlorococcus',
#  'JFKR01': 'Prochlorococcus',
#  'JFKS01': 'Prochlorococcus',
#  'JFKT01': 'Prochlorococcus',
#  'JFKU01': 'Prochlorococcus',
#  'JFKV01': 'Prochlorococcus',
#  'JFKW01': 'Prochlorococcus',
#  'JFKX01': 'Prochlorococcus',
#  'JFKY01': 'Prochlorococcus',
#  'JFKZ01': 'Prochlorococcus',
#  'JFLA01': 'Prochlorococcus',
#  'JFLB01': 'Prochlorococcus',
#  'JFLC01': 'Prochlorococcus',
#  'JFLD01': 'Prochlorococcus',
#  'JFLE01': 'Prochlorococcus',
#  'JFLF01': 'Prochlorococcus',
#  'JFLG01': 'Prochlorococcus',
#  'JFLH01': 'Prochlorococcus',
#  'JFLI01': 'Prochlorococcus',
#  'JFLJ01': 'Prochlorococcus',
#  'JFLK01': 'Prochlorococcus',
#  'JFLL01': 'Prochlorococcus',
#  'JFLM01': 'Prochlorococcus',
#  'JFLN01': 'Prochlorococcus',
#  'JFLO01': 'Prochlorococcus',
#  'JFLP01': 'Prochlorococcus',
#  'JFLQ01': 'Prochlorococcus',
#  'JFLR01': 'Prochlorococcus',
#  'JFLS01': 'Prochlorococcus',
#  'JFLT01': 'Prochlorococcus',
#  'JFLU01': 'Prochlorococcus',
#  'JFLV01': 'Prochlorococcus',
#  'JFLW01': 'Prochlorococcus',
#  'JFLX01': 'Prochlorococcus',
#  'JFLY01': 'Prochlorococcus',
#  'JFLZ01': 'Prochlorococcus',
#  'JFMA01': 'Prochlorococcus',
#  'JFMB01': 'Prochlorococcus',
#  'JFMC01': 'Prochlorococcus',
#  'JFMD01': 'Prochlorococcus',
#  'JFME01': 'Prochlorococcus',
#  'JFMF01': 'Prochlorococcus',
#  'JFMG01': 'Prochlorococcus',
#  'JFMH01': 'Prochlorococcus',
#  'JFMI01': 'Prochlorococcus',
#  'JFMJ01': 'Prochlorococcus',
#  'JFMK01': 'Prochlorococcus',
#  'JFML01': 'Prochlorococcus',
#  'JFMM01': 'Prochlorococcus',
#  'JFMN01': 'Prochlorococcus',
#  'JFMO01': 'Prochlorococcus',
#  'JFMP01': 'Prochlorococcus',
#  'JFMQ01': 'Prochlorococcus',
#  'JFMR01': 'Prochlorococcus',
#  'JFMS01': 'Prochlorococcus',
#  'JFMT01': 'Prochlorococcus',
#  'JFMU01': 'Prochlorococcus',
#  'JFMV01': 'Prochlorococcus',
#  'JFMW01': 'Prochlorococcus',
#  'JFMX01': 'Prochlorococcus',
#  'JFMY01': 'Prochlorococcus',
#  'JFMZ01': 'Prochlorococcus',
#  'JFNA01': 'Prochlorococcus',
#  'JFNB01': 'Prochlorococcus',
#  'JFNC01': 'Prochlorococcus',
#  'JFND01': 'Prochlorococcus',
#  'JFNE01': 'Prochlorococcus',
#  'JFNF01': 'Prochlorococcus',
#  'JFNG01': 'Prochlorococcus',
#  'JFNH01': 'Prochlorococcus',
#  'JFNI01': 'Prochlorococcus',
#  'JFNJ01': 'Prochlorococcus',
#  'JFNK01': 'Prochlorococcus',
#  'JFNL01': 'Prochlorococcus',
#  'JFNM01': 'Prochlorococcus',
#  'JFNN01': 'Prochlorococcus',
#  'JFNO01': 'Prochlorococcus',
#  'JFNP01': 'Prochlorococcus',
#  'JFNQ01': 'Prochlorococcus',
#  'JFNR01': 'Prochlorococcus',
#  'JFNS01': 'Prochlorococcus',
#  'JFNT01': 'Prochlorococcus',
#  'JFNU01': 'Prochlorococcus',
#  'JFNV01': 'Prochlorococcus',
#  'JFNW01': 'Prochlorococcus',
#  'JFNX01': 'Prochlorococcus',
#  'JFNY01': 'Prochlorococcus',
#  'JFNZ01': 'Prochlorococcus',
#  'JFOA01': 'Prochlorococcus',
#  'JFOB01': 'Prochlorococcus',
#  'JFOC01': 'Prochlorococcus',
#  'JFOD01': 'Prochlorococcus',
#  'JFOE01': 'Prochlorococcus',
#  'JHEG02': 'Tolypothrix',
#  'JJML01': 'Neosynechococcus',
#  'JMIX01': 'Erythrobacter',
#  'JMKF01': 'Leptolyngbya',
#  'JMRP01': 'Cyanobium',
#  'JNAG01': 'Prochlorococcus',
#  'JNAH01': 'Prochlorococcus',
#  'JNAI01': 'Prochlorococcus',
#  'JNAJ01': 'Prochlorococcus',
#  'JNAK01': 'Prochlorococcus',
#  'JNAL01': 'Prochlorococcus',
#  'JNAM01': 'Prochlorococcus',
#  'JNAN01': 'Prochlorococcus',
#  'JNAO01': 'Prochlorococcus',
#  'JNAP01': 'Prochlorococcus',
#  'JNAQ01': 'Prochlorococcus',
#  'JNAR01': 'Prochlorococcus',
#  'JNAS01': 'Prochlorococcus',
#  'JNAT01': 'Prochlorococcus',
#  'JNAU01': 'Prochlorococcus',
#  'JNAV01': 'Prochlorococcus',
#  'JNAW01': 'Prochlorococcus',
#  'JNAX01': 'Prochlorococcus',
#  'JNAY01': 'Prochlorococcus',
#  'JNAZ01': 'Prochlorococcus',
#  'JNBA01': 'Prochlorococcus',
#  'JNBB01': 'Prochlorococcus',
#  'JNBC01': 'Prochlorococcus',
#  'JNBD01': 'Prochlorococcus',
#  'JNBE01': 'Prochlorococcus',
#  'JPSP01': 'Atelocyanobacterium',
#  'JQFA01': 'Leptolyngbya',
#  'JRFE01': 'Myxosarcina',
#  'JSDP01': 'Aphanizomenon',
#  'JSUH01': 'Kocuria',
#  'JTCM01': 'Hassallia',
#  'JTHE01': 'Lyngbya',
#  'JTJC02': 'Scytonema',
#  'JTJD01': 'Aphanocapsa',
#  'JXCA01': 'Scytonema',
#  'JXCB01': 'Tolypothrix',
#  'JXIJ01': 'Mastigocladus',
#  'JXQG01': 'Synechococcus',
#  'JXUO01': 'Synechococcus',
#  'JXYX01': 'Microcystis',
#  'JYFQ01': 'Synechococcus',
#  'JYON01': 'Aliterella',
#  'LADK01': 'Trichodesmium',
#  'LAGX01': 'Nostoc',
#  'LAGY01': 'Nostoc',
#  'LAGZ01': 'Nostoc',
#  'LAHA01': 'Nostoc',
#  'LAHB01': 'Nostoc',
#  'LAHC01': 'Nostoc',
#  'LAHD01': 'Nostoc',
#  'LAHE01': 'Nostoc',
#  'LAHF01': 'Nostoc',
#  'LAHG01': 'Nostoc',
#  'LAHH01': 'Nostoc',
#  'LAHI01': 'Nostoc',
#  'LAHJ01': 'Nostoc',
#  'LAMW01': 'Trichodesmium',
#  'LATL02': 'Limnoraphis',
#  'LAYT01': 'Arthrospira',
#  'LFEK01': 'Synechococcus',
#  'LGSU01': 'Hydrocoleum',
#  'LICO01': 'Cyanobacterium',
#  'LIRE01': 'Pseudanabaena',
#  'LIRN01': 'Hapalosiphon',
#  'LIRO01': 'Limnothrix',
#  'LIUQ01': 'Planktothricoides',
#  'LJOP01': 'Anabaena',
#  'LJOQ01': 'Anabaena',
#  'LJOS01': 'Anabaena',
#  'LJOT01': 'Anabaena',
#  'LJOU01': 'Anabaena',
#  'LJOV01': 'Anabaena',
#  'LJOW01': 'Aphanizomenon',
#  'LJOX01': 'Aphanizomenon',
#  'LJOY01': 'Aphanizomenon',
#  'LJZR01': 'Phormidesmis',
#  'LJZT01': 'Phormidium',
#  'LMTZ01': 'Mastigocoleus',
#  'LMVE01': 'Cylindrospermopsis',
#  'LNAA01': 'Oscillatoriales',
#  'LNDC01': 'Geitlerinema',
#  'LSSA01': 'Nostoc',
#  'LSYZ01': 'Leptolyngbya',
#  'LSZA01': 'Phormidium',
#  'LTEC01': 'Aphanizomenon',
#  'LUBZ01': 'Cylindrospermopsis',
#  'LUFH01': 'Sphaerospermopsis',
#  'LUGL01': 'Elainella',
#  'LUHI01': 'Anabaena',
#  'LUHJ01': 'Anabaena',
#  'LUPS01': 'Prochlorococcus',
#  'LUPT01': 'Prochlorococcus',
#  'LUPU01': 'Prochlorococcus',
#  'LUPV01': 'Prochlorococcus',
#  'LURJ01': 'Synechococcus',
#  'LURK01': 'Synechococcus',
#  'LVHK01': 'Prochlorococcus',
#  'LVHL01': 'Prochlorococcus',
#  'LVHM01': 'Prochlorococcus',
#  'LVHN01': 'Prochlorococcus',
#  'LVHO01': 'Prochlorococcus',
#  'LVHP01': 'Prochlorococcus',
#  'LVHQ01': 'Prochlorococcus',
#  'LVHR01': 'Prochlorococcus',
#  'LVHS01': 'Prochlorococcus',
#  'LVHT01': 'Synechococcus',
#  'LVHU01': 'Synechococcus',
#  'LVHV01': 'Synechococcus',
#  'LWAJ01': 'Nodularia',
#  'LWHC01': 'Cyanobacterium',
#  'LWRO01': 'Geitlerinema',
#  'LXYR01': 'Phormidesmis',
#  'LYXA01': 'Cylindrospermopsis',
#  'LZQD01': 'Trichormus',
#  'MBQX01': 'Cylindrospermopsis',
#  'MBQY01': 'Cylindrospermopsis',
#  'MBRD01': 'Nostoc',
#  'MBRE01': 'Oscillatoriales',
#  'MBRF01': 'Limnothrix',
#  'MCIH01': 'Microcystis',
#  'MDVL01': 'Halothece',
#  'MDZH01': 'Microcystis',
#  'MJGC01': 'Desertifilum',
#  'MKGP01': 'Limnothrix',
#  'MKZR01': 'Moorea',
#  'MKZS01': 'Moorea',
#  'MLAW01': 'Roseofilum',
#  'MNHI01': 'Cyanobacteria',
#  'MNIV01': 'Cyanobacteria',
#  'MNPM01': 'Mastigocladus',
#  'MNYZ01': 'Oscillatoriales',
#  'MNZA01': 'Oscillatoriales',
#  'MOLN01': 'Microcystis',
#  'MOLZ01': 'Microcystis',
#  'MPMK01': 'Cyanobacteria',
#  'MPPI01': 'Phormidesmis',
#  'MQTZ01': 'Leptolyngbya',
#  'MRBY01': 'Limnothrix',
#  'MRBZ01': 'Nostoc',
#  'MRCA01': 'Fischerella',
#  'MRCB01': 'Hydrococcus',
#  'MRCC01': 'Chroogloeocystis',
#  'MRCD01': 'Calothrix',
#  'MRCE01': 'Phormidium',
#  'MRCF01': 'Scytonema',
#  'MRCG01': 'Phormidium',
#  'MRUD01': 'Synechococcus',
#  'MTAV01': 'Nostoc',
#  'MTAW01': 'Nostoc',
#  'MTAX01': 'Nostoc',
#  'MTBS01': 'Microcystis',
#  'MTBT01': 'Microcystis',
#  'MTBU01': 'Microcystis',
#  'MTPU01': 'Cylindrospermopsis',
#  'MTQM01': 'Microbacterium',
#  'MUGG01': 'Alkalinema',
#  'MVDI01': 'Chroococcidiopsis',
#  'MVGR01': 'Microcystis',
#  'MVOP01': 'Prochlorococcus',
#  'MWLD01': 'Synechococcus',
#  'MWLE01': 'Synechococcus',
#  'MWLF01': 'Synechococcus',
#  'MWLG01': 'Synechococcus',
#  'MWMJ01': 'Synechococcus',
#  'MWOO01': 'Prochlorococcus',
#  'MWOP01': 'Prochlorococcus',
#  'MWOQ01': 'Prochlorococcus',
#  'MWOR01': 'Prochlorococcus',
#  'MWOS01': 'Prochlorococcus',
#  'MWOT01': 'Prochlorococcus',
#  'MWOU01': 'Prochlorococcus',
#  'MWOV01': 'Prochlorococcus',
#  'MWOW01': 'Prochlorococcus',
#  'MWOX01': 'Prochlorococcus',
#  'MWOY01': 'Prochlorococcus',
#  'MWOZ01': 'Prochlorococcus',
#  'MWPA01': 'Prochlorococcus',
#  'MWPC01': 'Prochlorococcus',
#  'MWPD01': 'Prochlorococcus',
#  'MWPE01': 'Prochlorococcus',
#  'MWPF01': 'Prochlorococcus',
#  'MWPG01': 'Prochlorococcus',
#  'NBYN01': 'Cylindrospermopsis',
#  'NDGV01': 'Cyanobacterium',
#  'NDHW01': 'Pseudanabaena',
#  'NEED01': 'Unicellular',
#  'NETF01': 'Unicellular',
#  'NGZS01': 'Fischerella',
#  'NGZT01': 'Fischerella',
#  'NGZU01': 'Fischerella',
#  'NGZV01': 'Fischerella',
#  'NGZW01': 'Fischerella',
#  'NGZX01': 'Fischerella',
#  'NGZY01': 'Fischerella',
#  'NGZZ01': 'Fischerella',
#  'NHAA01': 'Fischerella',
#  'NHAB01': 'Fischerella',
#  'NHAC01': 'Fischerella',
#  'NHAD01': 'Fischerella',
#  'NHAE01': 'Fischerella',
#  'NHAF01': 'Fischerella',
#  'NHAG01': 'Fischerella',
#  'NHAH01': 'Fischerella',
#  'NHAI01': 'Fischerella',
#  'NHAJ01': 'Fischerella',
#  'NHAK01': 'Fischerella',
#  'NHBY01': 'Synechococcus',
#  'NHBZ01': 'Synechococcus',
#  'NHDT01': 'Synechococcus',
#  'NHER01': 'Synechococcus',
#  'NHHE01': 'Synechococcus',
#  'NHHS01': 'Synechococcus',
#  'NHIA01': 'Cyanobacteria',
#  'NHII01': 'Synechococcus',
#  'NHIK01': 'Synechococcus',
#  'NHIL01': 'Cyanobacteria',
#  'NHJC01': 'Synechococcus',
#  'NHJU01': 'Prochlorococcus',
#  'NHKA01': 'Cyanobacteria',
#  'NJHS01': 'Cylindrospermopsis',
#  'NJHT01': 'Cylindrospermopsis',
#  'NJHU01': 'Cylindrospermopsis',
#  'NJHV01': 'Cylindrospermopsis',
#  'NJHW01': 'Cylindrospermopsis',
#  'NJHX01': 'Cylindrospermopsis',
#  'NJHY01': 'Cylindrospermopsis',
#  'NJHZ01': 'Cylindrospermopsis',
#  'NJIA01': 'Cylindrospermopsis',
#  'NKFP01': 'Leptolyngbya',
#  'NMQA01': 'Fischerella',
#  'NMQB01': 'Fischerella',
#  'NMQC01': 'Fischerella',
#  'NMQD01': 'Fischerella',
#  'NMQE01': 'Fischerella',
#  'NMQF01': 'Fischerella',
#  'NMQG01': 'Fischerella',
#  'NMQH01': 'Fischerella',
#  'NMQI01': 'Fischerella',
#  'NMQJ01': 'Fischerella',
#  'NMQK01': 'Fischerella',
#  'NOLI01': 'Nostoc',
#  'NOLJ01': 'Nostoc',
#  'NOLK01': 'Nostoc',
#  'NOXS01': 'Elstera',
#  'NOXT01': 'Sandarakinorhabdus',
#  'NOXU01': 'Niveispirillum',
#  'NOXV01': 'Flavobacterium',
#  'NOXW01': 'Rhodoferax',
#  'NOXX01': 'Flavobacterium',
#  'NPIK01': 'Cylindrospermopsis',
#  'NPIL01': 'Cylindrospermopsis',
#  'NQKW01': 'Synechococcus',
#  'NQKX01': 'Synechococcus',
#  'NQKY01': 'Synechococcus',
#  'NQKZ01': 'Synechococcus',
#  'NQLA01': 'Synechococcus',
#  'NQMD01': 'Fischerella',
#  'NQME01': 'Fischerella',
#  'NQMF01': 'Fischerella',
#  'NRIU01': 'Geitlerinema',
#  'NRQW01': 'Fischerella',
#  'NRTA01': 'Leptolyngbya',
#  'NSHF01': 'Nostoc',
#  'NSHT01': 'Cyanobium',
#  'NSII01': 'Synechococcus',
#  'NTFS01': 'Calothrix',
#  'NXIB02': 'Tychonema',
#  'NYUU01': 'Synechococcus',
#  'NYXI01': 'Synechococcus',
#  'NYZI01': 'Cyanobium',
#  'NZED01': 'Synechococcus',
#  'NZHI01': 'Synechococcus',
#  'NZHY01': 'Prochlorococcus',
#  'NZJI01': 'Cyanobium',
#  'NZKA01': 'Prochlorococcus',
#  'NZPI01': 'Synechococcus',
#  'NZVB01': 'Cyanobium',
#  'NZXF01': 'Synechococcus',
#  'PAEP01': 'Synechococcus',
#  'PAEU01': 'Cyanobium',
#  'PAJY01': 'Synechococcus',
#  'PAXG01': 'Cyanobium',
#  'PBHJ01': 'Prochlorococcus',
#  'PBPY01': 'Synechococcus',
#  'PBVK01': 'Cyanobium',
#  'PBYZ01': 'Synechococcus',
#  'PCGE01': 'Synechococcus',
#  'PDDM01': 'Pseudanabaena',
#  'PEBC01': 'Cyanobacterium',
#  'PEIG01': 'Chroococcales',
#  'PESY01': 'Prochlorococcus',
#  'PGEM01': 'Cuspidothrix',
#  'PHFO01': 'Cyanobacteria',
#  'PKDM01': 'Cyanobacterium',
#  'PKDN01': 'Cyanobacterium',
#  'PKRO01': 'Porphyrobacter',
#  'PKRP01': 'Rhizobium',
#  'PKRQ01': 'Tabrizicola',
#  'PKRR01': 'Uliginosibacterium',
#  'PKRS01': 'Emticicia',
#  'PKRT01': 'Novosphingobium',
#  'PRLH01': 'Cyanothece',
#  'PTJN01': 'Gloeocapsopsis',
#  'PVWD01': 'Filamentous',
#  'PVWE01': 'Filamentous',
#  'PVWF01': 'Pleurocapsa',
#  'PVWG01': 'Phormidesmis',
#  'PVWH01': 'Filamentous',
#  'PVWI01': 'Filamentous',
#  'PVWJ01': 'Merismopedia',
#  'PVWK01': 'Leptolyngbya',
#  'PVWL01': 'Cyanosarcina',
#  'PVWM01': 'Chroococcidiopsis',
#  'PVWN01': 'Chlorogloea',
#  'PVWO01': 'Chamaesiphon',
#  'PVWP01': 'Aphanothece',
#  'PXOH01': 'Aphanothece',
#  'PXPI01': 'Cyanobacteria',
#  'PXPJ01': 'Cyanobacteria',
#  'PXPK01': 'Cyanobacteria',
#  'PXPL01': 'Cyanobacteria',
#  'PXPM01': 'Cyanobacteria',
#  'PXPN01': 'Cyanobacteria',
#  'PXPO01': 'Cyanobacteria',
#  'PXPP01': 'Cyanobacteria',
#  'PXPQ01': 'Cyanobacteria',
#  'PXPR01': 'Cyanobacteria',
#  'PXPS01': 'Cyanobacteria',
#  'PXPT01': 'Cyanobacteria',
#  'PXPU01': 'Cyanobacteria',
#  'PXPV01': 'Cyanobacteria',
#  'PXPW01': 'Cyanobacteria',
#  'PXPX01': 'Cyanobacteria',
#  'PXPY01': 'Cyanobacteria',
#  'PXPZ01': 'Cyanobacteria',
#  'PXQA01': 'Cyanobacteria',
#  'PXQB01': 'Cyanobacteria',
#  'PXQC01': 'Cyanobacteria',
#  'PXQD01': 'Cyanobacteria',
#  'PXQE01': 'Cyanobacteria',
#  'PXQF01': 'Cyanobacteria',
#  'PXQG01': 'Cyanobacteria',
#  'PXQH01': 'Cyanobacteria',
#  'PXQI01': 'Cyanobacteria',
#  'PXVC01': 'Synechococcus',
#  'PXXO01': 'Cyanobium',
#  'PYCI01': 'Chroococcidiopsis',
#  'PYEQ01': 'Filamentous',
#  'PYER01': 'Filamentous',
#  'PYFY01': 'Filamentous',
#  'PYGV01': 'Filamentous'}

# %%
import csv

with open('/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash_taxonomy.csv', 'wb') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in taxa_dict.items():
       writer.writerow([key, value])

# %% [markdown]
# **Obtaining MASH distances from a given Cyanobiome finished genome to a NCBI reference**

# %%
def get_mash_df(inputs_folder,sketch):
    start_time = time.time()
    input_list = glob.glob("%s*.fasta"%inputs_folder)
    final_df = pd.DataFrame()
    for index,item in enumerate(input_list):
        scores = []
        cmd = "/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash dist %s %s > /home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/temp.txt"%(sketch,item)
        subprocess.call(cmd,shell=True)
#         print cmd
        df = pd.read_csv("/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/temp.txt",sep="\t",names=["reference","query","distance","pvalue","matching-hashes"])
        df = df[df.reference != item]
        row = df[df.distance == df.distance.min()]
        final_df = final_df.append(row[:1], ignore_index = True)
    print('\n' + "--- %s seconds ---" %(time.time()-start_time))
    return final_df
        
mash_df = get_mash_df("/home/tiago/Desktop/cyanet/cyanobiome/final_scaffolds/","/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/ncbi_genomes.msh")
# Out:
# --- 63.8576719761 seconds ---

# %%
for item in mash_df['reference']:
    print item
# Out:
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/JTHE01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MJGC01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ABRS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ALVP01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LUFH01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ABRS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AQPY01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/PRLH01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ABRS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AWNH01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/NKFP01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LUFH01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ABRS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/PVWJ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/BBWW01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AGJC02.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ALVI01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MRCF01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ALVV02.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ALVQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ABRS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AJWF01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ALVI01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/JMKF01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/BBPA01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AEPQ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/ABRS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/NSHF01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/NOLJ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/MKZS01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/LGSU01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/CZDF01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/CAIJ01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AUZM01.ren.fasta
# /home/gerwick-lab/Desktop/data/genomes/refseq_cyano/renamed/AGJC02.ren.fasta

# %% [markdown]
# **Number of singletons using MASH paper metric of D ≤ 0.05 and p-value ≤ 10E–10**

# %%
75-len(mash_df[mash_df["distance"] <= 0.05])
# Out:
# 54

# %%
mash_df[mash_df["distance"] <= 0.05]["pvalue"]
# Out:
# 1     0.0
# 2     0.0
# 10    0.0
# 12    0.0
# 14    0.0
# 15    0.0
# 16    0.0
# 20    0.0
# 23    0.0
# 25    0.0
# 26    0.0
# 33    0.0
# 36    0.0
# 37    0.0
# 39    0.0
# 40    0.0
# 45    0.0
# 51    0.0
# 63    0.0
# 66    0.0
# 68    0.0
# Name: pvalue, dtype: float64

# %% [markdown]
# **Obtaining closest taxa for Cyanobiome genomes**

# %%
taxa_dict2 = {}

for i,r in mash_df.iterrows():
    ncbi_taxa = os.path.splitext(os.path.basename((r[0])))[0].partition('.')[0]
    strain = os.path.splitext(os.path.basename((r[1])))[0].partition('_')[0]
    taxa_dict2[strain] = taxa_dict[ncbi_taxa]

# %%
taxa_dict2
# Out:
# {'1A2': 'Moorea',
#  '1A3': 'Moorea',
#  '1A7': 'Nostoc',
#  '1B1': 'Coleofasciculus',
#  '1B6': 'Leptolyngbya',
#  '1B8': 'Hydrocoleum',
#  '1C1': 'Hydrocoleum',
#  '1C2': 'Microcystis',
#  '1C4': 'Cyanothece',
#  '1C9': 'Moorea',
#  '1D4': 'Moorea',
#  '1D8': 'Kamptonema',
#  '1D9': 'Microcystis',
#  '1E1': 'Kamptonema',
#  '1E3': 'Moorea',
#  '1E4': 'Leptolyngbya',
#  '1F2': 'Moorea',
#  '1F9': 'Hydrocoleum',
#  '1G1': 'Sphaerospermopsis',
#  '1G2': 'Sphaerospermopsis',
#  '1G6': 'Moorea',
#  '1H2': 'Hydrocoleum',
#  '1H4': 'Hydrocoleum',
#  '1H5': 'Hydrocoleum',
#  '1H6': 'Hydrocoleum',
#  '1I2': 'Desertifilum',
#  '1I4': 'Coleofasciculus',
#  '1I7': 'Hydrocoleum',
#  '2A8': 'Merismopedia',
#  '2A9': 'Lyngbya',
#  '2B3': 'Hydrocoleum',
#  '2B6': 'Nostoc',
#  '2B7': 'Moorea',
#  '2B9': 'Hydrocoleum',
#  '2C1': 'Coleofasciculus',
#  '2C2': 'Hydrocoleum',
#  '2C4': 'Moorea',
#  '2C9': 'Hydrocoleum',
#  '2D1': 'Hydrocoleum',
#  '2D2': 'Microcystis',
#  '2D8': 'Hydrocoleum',
#  '2E6': 'Coleofasciculus',
#  '2E9': 'Coleofasciculus',
#  '2F4': 'Hydrocoleum',
#  '2F5': 'Hydrocoleum',
#  '2G3': 'Scytonema',
#  '2G4': 'Hydrocoleum',
#  '2G5': 'Hydrocoleum',
#  '2G6': 'Anabaena',
#  '2G7': 'Coleofasciculus',
#  '2G8': 'Nostoc',
#  '2H1': 'Moorea',
#  '2H7': 'Hydrocoleum',
#  '2I5': 'Moorea',
#  '2I6': 'Moorea',
#  '2I9': 'Hydrocoleum',
#  '3A1': 'Moorea',
#  '3A2': 'Moorea',
#  '3A5': 'Moorea',
#  '3B2': 'Moorea',
#  '3B3': 'Hydrocoleum',
#  '3B5': 'Hydrocoleum',
#  '3C2': 'Moorea',
#  '3C4': 'Hydrocoleum',
#  '3C6': 'Cyanothece',
#  '3E2': 'Moorea',
#  '3E6': 'Coleofasciculus',
#  '3E8': 'Moorea',
#  '3F1': 'Hydrocoleum',
#  '3F2': 'Spirulina',
#  '3F3': 'Lyngbya',
#  '3F4': 'Leptolyngbya',
#  '3F7': 'Moorea',
#  '3G5': 'Moorea',
#  '3H1': 'Hydrocoleum',
#  '3H5': 'Moorea',
#  '3I5': 'Hydrocoleum',
#  '3I6': 'Moorea',
#  '3I7': 'Moorea',
#  '3I8': 'Moorea',
#  '4A1': 'Moorea',
#  '4A3': 'Moorea',
#  '4A5': 'Moorea',
#  '4A6': 'Myxosarcina',
#  '4A8': 'Hydrocoleum',
#  '4B1': 'Coleofasciculus',
#  '4B2': 'Hydrocoleum',
#  '4B7': 'Kamptonema',
#  '4B8': 'Moorea',
#  '4C1': 'Nodosilinea',
#  '4C4': 'Cyanothece',
#  '4C5': 'Leptolyngbya',
#  '4C7': 'Moorea',
#  '4C8': 'Hydrocoleum',
#  '4D6': 'Hydrocoleum',
#  '4D7': 'Moorea',
#  '4E2': 'Moorea',
#  '4G2': 'Moorea',
#  '4G3': 'Moorea',
#  'ISBB': 'Lyngbya'}

# %% [markdown]
# **Correcting noomeclature replacing with manually online BLAST searched 16S rRNA**

# %%
taxa_dict3 = {}

for item in taxa_dict2:
    if taxa_dict2[item] != "Hydrocoleum":
        taxa_dict3[item] = taxa_dict2[item]
    else:
        taxa_dict3[item] = "Okeania"
    if item == "ISBB":
        taxa_dict3[item] = "Leptolyngbya"

# %%
taxa_dict3
# Out:
# {'1A2': 'Moorea',
#  '1A3': 'Moorea',
#  '1A7': 'Nostoc',
#  '1B1': 'Coleofasciculus',
#  '1B6': 'Leptolyngbya',
#  '1B8': 'Okeania',
#  '1C1': 'Okeania',
#  '1C2': 'Microcystis',
#  '1C4': 'Cyanothece',
#  '1C9': 'Moorea',
#  '1D4': 'Moorea',
#  '1D8': 'Kamptonema',
#  '1D9': 'Microcystis',
#  '1E1': 'Kamptonema',
#  '1E3': 'Moorea',
#  '1E4': 'Leptolyngbya',
#  '1F2': 'Moorea',
#  '1F9': 'Okeania',
#  '1G1': 'Sphaerospermopsis',
#  '1G2': 'Sphaerospermopsis',
#  '1G6': 'Moorea',
#  '1H2': 'Okeania',
#  '1H4': 'Okeania',
#  '1H5': 'Okeania',
#  '1H6': 'Okeania',
#  '1I2': 'Desertifilum',
#  '1I4': 'Coleofasciculus',
#  '1I7': 'Okeania',
#  '2A8': 'Merismopedia',
#  '2A9': 'Lyngbya',
#  '2B3': 'Okeania',
#  '2B6': 'Nostoc',
#  '2B7': 'Moorea',
#  '2B9': 'Okeania',
#  '2C1': 'Coleofasciculus',
#  '2C2': 'Okeania',
#  '2C4': 'Moorea',
#  '2C9': 'Okeania',
#  '2D1': 'Okeania',
#  '2D2': 'Microcystis',
#  '2D8': 'Okeania',
#  '2E6': 'Coleofasciculus',
#  '2E9': 'Coleofasciculus',
#  '2F4': 'Okeania',
#  '2F5': 'Okeania',
#  '2G3': 'Scytonema',
#  '2G4': 'Okeania',
#  '2G5': 'Okeania',
#  '2G6': 'Anabaena',
#  '2G7': 'Coleofasciculus',
#  '2G8': 'Nostoc',
#  '2H1': 'Moorea',
#  '2H7': 'Okeania',
#  '2I5': 'Moorea',
#  '2I6': 'Moorea',
#  '2I9': 'Okeania',
#  '3A1': 'Moorea',
#  '3A2': 'Moorea',
#  '3A5': 'Moorea',
#  '3B2': 'Moorea',
#  '3B3': 'Okeania',
#  '3B5': 'Okeania',
#  '3C2': 'Moorea',
#  '3C4': 'Okeania',
#  '3C6': 'Cyanothece',
#  '3E2': 'Moorea',
#  '3E6': 'Coleofasciculus',
#  '3E8': 'Moorea',
#  '3F1': 'Okeania',
#  '3F2': 'Spirulina',
#  '3F3': 'Lyngbya',
#  '3F4': 'Leptolyngbya',
#  '3F7': 'Moorea',
#  '3G5': 'Moorea',
#  '3H1': 'Okeania',
#  '3H5': 'Moorea',
#  '3I5': 'Okeania',
#  '3I6': 'Moorea',
#  '3I7': 'Moorea',
#  '3I8': 'Moorea',
#  '4A1': 'Moorea',
#  '4A3': 'Moorea',
#  '4A5': 'Moorea',
#  '4A6': 'Myxosarcina',
#  '4A8': 'Okeania',
#  '4B1': 'Coleofasciculus',
#  '4B2': 'Okeania',
#  '4B7': 'Kamptonema',
#  '4B8': 'Moorea',
#  '4C1': 'Nodosilinea',
#  '4C4': 'Cyanothece',
#  '4C5': 'Leptolyngbya',
#  '4C7': 'Moorea',
#  '4C8': 'Okeania',
#  '4D6': 'Okeania',
#  '4D7': 'Moorea',
#  '4E2': 'Moorea',
#  '4G2': 'Moorea',
#  '4G3': 'Moorea',
#  'ISBB': 'Leptolyngbya'}

# %%
import csv

with open('/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash_taxonomy.csv', 'a') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in taxa_dict3.items():
       writer.writerow([key, value])

# %% [markdown]
# The final taxonomy on the MASH file ("mash_taxonomy_2.csv") was manually corrected using 16S assigments and phylogenomic clading

# %% [markdown]
# **Attaching new column to master_df**

# %%
mash_df = pd.read_csv('/home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash_taxonomy_2.csv',sep=',',header=None)

new_names = []

for i,r in mash_df.iterrows():
    if len(mash_df[0].loc[i]) <= 4:
        strain = "SIO"+mash_df[0].loc[i]
        new_names.append(strain)
    else:
        new_names.append(mash_df[0].loc[i])
        
mash_df[0] = new_names

mash_dict = pd.Series(mash_df[1].values,index=mash_df[0]).to_dict()

# %%
mash_df[:5]
# Out:
#         0                1
# 0  NRIU01     Geitlerinema
# 1  LUPT01  Prochlorococcus
# 2  MWPC01  Prochlorococcus
# 3  AVFY01     Planktothrix
# 4  JFLU01  Prochlorococcus

# %%
master_df = pd.read_csv("/home/tiago/Desktop/cyanet/cyanobiome/tables/master_df-TFL190425.txt",sep="\t")

master_df
# Out:
#             collectionID genomeID  completeness  #scaffolds     GC  #fragBGCs  \
# 0         ASG15JUL146CUL   SIO3F2         99.09         454  49.40         10
# 1         ASX22JUL142CUL   SIO1E4         99.73         659  52.29         12
# 2          CobbledownCUL   SIO4C1         99.18         849  53.63         21
# 3              numC11CUL   SIO4C4         94.38        1496  46.66          4
# 4             numC15BCUL   SIO4C5         98.64        1204  52.29         15
# 5         PAB16MAY116CUL   SIO3F4         98.91        1509  45.42          9
# 6         PAB18MAY119CUL   SIO1E1         99.18        1398  46.96         23
# 7         PAL23MAY131CUL   SIO1I2         98.51        1046  47.98         10
# 8   PAL24MAY135-contACUL   SIO1I4         99.46         245  53.06         11
# 9         PAP25JUN122CUL   SIO1D8         97.09        1787  48.24          9
# 10  PhormidiumspChinaCUL   SIO1D9         99.05         332  41.87         16
# 11        PNG22APR061CUL   SIO3F7         98.91         399  43.74         22
# 12        ASF14JUL142ENV   SIO1B1         97.06        1462  42.38         28
# 13        ASG15JUL146ENV   SIO1B6         99.37         265  49.04          8
# 14        ASG15JUL148ENV   SIO1C4         96.97        1267  42.79         14
# 15        ASI16JUL142ENV   SIO1A2         95.97        2584  43.51         23
# 16        ASI16JUL144ENV   SIO1A3         99.18        1374  43.11         22
# 17        ASI16JUL149ENV   SIO1A7         99.64         183  47.07          6
# 18        AST13JUL143ENV   SIO1F2         98.51         688  43.36         14
# 19        ASY22JUL141ENV   SIO1C2         99.09         246  43.14         16
# 20        GBB21MAR161ENV   SIO4G2         90.26        3478  43.58          4
# 21        GGG21MAR161ENV   SIO4G3         98.82         777  43.47         48
# 22        NAC09DEC082ENV   SIO1I7         99.73         110  37.02          5
# 23        NAC18DEC082ENV   SIO3A5         98.91         164  43.28         17
# 24        PAB03APR065ENV   SIO1H2         99.73         279  37.40         11
# 25        PAB05APR064ENV   SIO1H4         99.46         192  36.77         11
# 26        PAB07APR054ENV   SIO1H5         99.59         263  39.72         13
# 27        PAB07APR055ENV   SIO1H6         98.14        1436  36.46         13
# 28        PAB16MAY112ENV   SIO2A8         97.03        3058  45.47          2
# 29        PAB16MAY113ENV   SIO2B7         98.23        1655  41.31         16
# ..                   ...      ...           ...         ...    ...        ...
# 51        PAL24MAY135ENV   SIO2H7         91.55        4053  39.06          3
# 52        PAP14JUN083ENV   SIO3C6        100.00         290  44.97          6
# 53        PAP15JUN091ENV   SIO4E2         97.83        1452  43.18         30
# 54        PAP15JUN097ENV   SIO3B2         97.28        1018  43.12         23
# 55        PAP23MAR121ENV   SIO3B3         95.88        2567  37.49         13
# 56        PAP23MAR125ENV   SIO3I5         99.91         563  36.37          9
# 57        PAP25JUN121ENV   SIO3E6         95.15        1884  43.21         16
# 58        PAP25JUN122ENV   SIO3A1         97.28         772  43.29         18
# 59        PAP28JUN071ENV   SIO3E2         92.53        2452  43.75          3
# 60        PLP20MAR122ENV   SIO3E8         98.91         387  43.82         23
# 61        PNG01MAY071ENV   SIO2E6         98.91        1438  43.33         23
# 62        PNG11DEC03AENV   SIO3H1         98.64        1134  36.62         11
# 63       PNG12JUL0731ENV   SIO3I6         98.64        1790  42.97         13
# 64        PNG12JUL075ENV   SIO3I7         94.93        3188  43.10         13
# 65        PNG12JUL076ENV   SIO3I8         98.91         511  43.22         15
# 66        PNG13DEC032ENV   SIO3H5         98.14         835  42.95         38
# 67        PNG13JUL072ENV   SIO4A1         98.37        1106  42.92         13
# 68        PNG13JUL078ENV   SIO3B5         99.09         790  36.89         18
# 69        PNG15JUL074ENV   SIO4A3         92.39        1522  43.39         40
# 70        PNG16DEC032ENV   SIO3G5         95.65        2144  43.72         28
# 71        PNG16JUL074ENV   SIO4A5         98.01         605  43.29         15
# 72        PNG21MAY053ENV   SIO2E9         99.37         384  43.50         16
# 73        PRL23MAR111ENV   SIO1F9         99.73         198  36.79          5
# 74        PRL23MAR113ENV   SIO1G1        100.00          39  38.61          4
# 75        PRM24MAR111ENV   SIO1G2         98.37        1028  38.38          7
# 76        PRM25MAR112ENV   SIO1G6         98.91         205  43.27         20
# 77        SPB31JAN131ENV   SIO3A2         98.91         132  43.36         23
# 78        VQD27MAR117ENV   SIO3C2         95.11        2364  44.02         23
# 79        ISB3NOV948BCUL  SIOISBB        100.00           3  52.10          0
# 80        ASI16JUL142CUL  SIOASIH         98.91          25  46.33          5
#
#     #completeBGCs  #allBGCs
# 0               0        10
# 1              18        30
# 2               4        25
# 3               2         6
# 4               0        15
# 5               0         9
# 6               1        24
# 7               4        14
# 8               0        11
# 9               0         9
# 10              2        18
# 11              7        29
# 12              1        29
# 13              8        16
# 14              0        14
# 15              0        23
# 16              0        22
# 17              8        14
# 18              0        14
# 19             11        27
# 20              0         4
# 21              2        50
# 22             12        17
# 23             11        28
# 24              2        13
# 25              3        14
# 26              3        16
# 27              0        13
# 28              0         2
# 29              0        16
# ..            ...       ...
# 51              0         3
# 52             11        17
# 53              0        30
# 54              3        26
# 55              0        13
# 56              2        11
# 57              0        16
# 58              2        20
# 59              0         3
# 60              7        30
# 61              0        23
# 62              0        11
# 63              2        15
# 64              0        13
# 65              4        19
# 66              2        40
# 67              4        17
# 68              0        18
# 69              0        40
# 70              0        28
# 71              3        18
# 72              5        21
# 73              6        11
# 74              6        10
# 75              0         7
# 76             12        32
# 77              8        31
# 78              0        23
# 79             11        11
# 80             41        46
#
# [81 rows x 8 columns]

# %%
taxa_col = []

for i,r in master_df.iterrows():
    strain = master_df.loc[i]["genomeID"]
    taxa_col.append(mash_dict[strain])
    
master_df["MASH-taxa"] = taxa_col

master_df[:5]
# Out:
#      collectionID genomeID  completeness  #scaffolds     GC  #fragBGCs  \
# 0  ASG15JUL146CUL   SIO3F2         99.09         454  49.40         10
# 1  ASX22JUL142CUL   SIO1E4         99.73         659  52.29         12
# 2   CobbledownCUL   SIO4C1         99.18         849  53.63         21
# 3       numC11CUL   SIO4C4         94.38        1496  46.66          4
# 4      numC15BCUL   SIO4C5         98.64        1204  52.29         15
#
#    #completeBGCs  #allBGCs     MASH-taxa
# 0              0        10     Spirulina
# 1             18        30  Leptolyngbya
# 2              4        25  Leptolyngbya
# 3              2         6    Kamptonema
# 4              0        15  Leptolyngbya

# %%
master_df.to_csv("/home/tiago/Desktop/cyanet/cyanobiome/tables/master_df-TFL190425-taxaID.txt",sep="\t",index_label=False)

# %%
# !cp /home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash_taxonomy.csv /home/tiago/Desktop/cyanet/genomics_pnas/outputs/
# !cp /home/tiago/Desktop/cyanet/cyanobiome/mash-Linux64-v2.0/mash_taxonomy_2.csv /home/tiago/Desktop/cyanet/genomics_pnas/outputs/
# !cp /home/tiago/Desktop/cyanet/cyanobiome/tables/master_df-TFL190425-taxaID.txt /home/tiago/Desktop/cyanet/genomics_pnas/outputs/

# %% [markdown]
# ```
# Outputs: mash_taxonomy.csv
#          mash_taxonomy_2.csv
#          master_df-TFL190425-taxaID.txt
# ```
